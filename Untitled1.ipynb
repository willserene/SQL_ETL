# %%
import pandas as pd
from sqlalchemy import create_engine
from password import password

# %%
# read game_goalie_stats csv to df
goalie_stats_file = "data/game_goalie_stats.csv"
game_goalie_df = pd.read_csv(goalie_stats_file)
game_goalie_df.head(5)
# Out:
#       game_id  player_id  team_id  timeOnIce  assists  goals  pim  shots  \
# 0  2016020045    8473607        4       1504        0      0    0     16
# 1  2016020045    8473461        4       2011        0      0    0     11
# 2  2016020045    8470645       16       3598        0      0    0     27
# 3  2017020812    8468011       24       3696        0      0    0     33
# 4  2017020812    8475215        7       3539        0      0    0     33
#
#    saves  powerPlaySaves  shortHandedSaves  evenSaves  \
# 0     12               1                 0         11
# 1      9               1                 0          8
# 2     23               2                 0         21
# 3     30               1                 2         27
# 4     29               4                 1         24
#
#    shortHandedShotsAgainst  evenShotsAgainst  powerPlayShotsAgainst decision  \
# 0                        0                13                      3      NaN
# ...

# %%
game_plays_players_file = "data/game_plays_players.csv"
game_plays_players_df = pd.read_csv(game_plays_players_file)
game_plays_players_df.head(5)
# Out:
#         play_id     game_id  player_id playerType
# 0  2016020045_4  2016020045    8473604     Winner
# 1  2016020045_4  2016020045    8473512      Loser
# 2  2016020045_5  2016020045    8473573    Shooter
# 3  2016020045_5  2016020045    8473607     Goalie
# 4  2016020045_6  2016020045    8474141     Scorer

# %%
player_info_file = "data/player_info.csv"
player_info_df = pd.read_csv(player_info_file)
player_info_df.head(5)
# Out:
#    player_id firstName      lastName nationality       birthCity  \
# 0    8466148    Marian         Hossa         SVK   Stará Lubovna
# 1    8465058    Michal      Rozsival         CZE          Vlasim
# 2    8476906    Shayne  Gostisbehere         USA  Pembroke Pines
# 3    8466285     Brian      Campbell         CAN       Strathroy
# 4    8470607     Brent      Seabrook         CAN        Richmond
#
#   primaryPosition            birthDate birthStateProvince  height  height_cm  \
# 0              RW  1979-01-12 00:00:00                NaN   6' 1"     185.42
# 1               D  1978-09-03 01:00:00                NaN   6' 1"     185.42
# 2               D  1993-04-20 01:00:00                 FL  5' 11"     180.34
# 3               D  1979-05-23 01:00:00                 ON  5' 10"     177.80
# 4               D  1985-04-20 01:00:00                 BC   6' 3"     190.50
#
#    weight shootsCatches
# 0   207.0             L
# 1   210.0             R
# 2   180.0             L
# ...

# %%
# create connector
#rds_connection_string = f"postgres:{password}@localhost:5432/hockey_db"
#engine = create_engine(f'postgresql://{rds_connection_string}')
# display tables in database

engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/hockey_db')

# display tables in database
engine.table_names()
# Out:
# ['game_goalie_stats', 'player_info', 'game_plays_players']
