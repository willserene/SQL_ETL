# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
scratches_file = "Data/game_scratches.csv"
scratches_df = pd.read_csv(scratches_file)
scratches_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-27-99316ff341e9> in <module>
#       1 scratches_file = "Data/game_scratches.csv"
# ----> 2 scratches_df = pd.read_csv(scratches_file)
#       3 scratches_df.head(5)
#
# ...

# %%
game_file = "Data/game.csv"
game_df = pd.read_csv(game_file)
game_df.head(5)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-28-9329938bb123> in <module>
#       1 game_file = "Data/game.csv"
# ----> 2 game_df = pd.read_csv(game_file)
#       3 game_df.head(5)
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# ...

# %%
team_info_file = "Data/team_info.csv"
team_df = pd.read_csv(team_info_file)
team_df.head(5)
# Out:
#    team_id  franchiseId     shortName   teamName abbreviation  \
# 0        1           23    New Jersey     Devils          NJD
# 1        4           16  Philadelphia     Flyers          PHI
# 2       26           14   Los Angeles      Kings          LAK
# 3       14           31     Tampa Bay  Lightning          TBL
# 4        6            6        Boston     Bruins          BOS
#
#                link
# 0   /api/v1/teams/1
# 1   /api/v1/teams/4
# 2  /api/v1/teams/26
# 3  /api/v1/teams/14
# 4   /api/v1/teams/6

# %%
rds_connection_string = ":<insert password>@localhost:5432/customer_db"
engine = create_engine(f'postgresql://{rds_connection_string}')
# display tables in database
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2335         try:
# -> 2336             return fn()
#    2337         except dialect.dbapi.Error as e:
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     363         if not self._use_threadlocal:
# --> 364             return _ConnectionFairy._checkout(self)
#     365
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     777         if not fairy:
# --> 778             fairy = _ConnectionRecord.checkout(pool)
#     779
#
# ~\anaconda3\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     494     def checkout(cls, pool):
# --> 495         rec = pool._do_get()
#     496         try:
#
# ...
