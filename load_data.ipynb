# %%
import pandas as pd
from sqlalchemy import create_engine
from password import password

# %% [markdown]
# ### Load CSVs to Dataframes

# %%
game_file = "data/game.csv"
game_df = pd.read_csv(game_file)
game_df.head(5)
# Out:
#       game_id    season type         date_time_GMT  away_team_id  \
# 0  2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1  2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2  2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3  2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4  2017020586  20172018    R  2017-12-30T03:00:00Z            20
#
#    home_team_id  away_goals  home_goals       outcome home_rink_side_start  \
# 0            16           4           7  home win REG                right
# 1             7           4           3   away win OT                 left
# 2            52           4           1  away win REG                right
# 3            12           1           2  home win REG                right
# 4            24           1           2  home win REG                 left
#
#             venue           venue_link   venue_time_zone_id  \
# 0   United Center  /api/v1/venues/null      America/Chicago
# 1  KeyBank Center  /api/v1/venues/null     America/New_York
# 2      MTS Centre  /api/v1/venues/null     America/Winnipeg
# 3       PNC Arena  /api/v1/venues/null     America/New_York
# 4    Honda Center  /api/v1/venues/null  America/Los_Angeles
#
#    venue_time_zone_offset venue_time_zone_tz
# 0                      -5                CDT
# 1                      -4                EDT
# 2                      -5                CDT
# 3                      -4                EDT
# 4                      -7                PDT

# %%
game_plays_file = "data/game_plays.csv"
game_plays_df = pd.read_csv(game_file)
game_plays_df.head(5)
# Out:
#       game_id    season type         date_time_GMT  away_team_id  \
# 0  2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1  2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2  2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3  2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4  2017020586  20172018    R  2017-12-30T03:00:00Z            20
#
#    home_team_id  away_goals  home_goals       outcome home_rink_side_start  \
# 0            16           4           7  home win REG                right
# 1             7           4           3   away win OT                 left
# 2            52           4           1  away win REG                right
# 3            12           1           2  home win REG                right
# 4            24           1           2  home win REG                 left
#
#             venue           venue_link   venue_time_zone_id  \
# 0   United Center  /api/v1/venues/null      America/Chicago
# 1  KeyBank Center  /api/v1/venues/null     America/New_York
# 2      MTS Centre  /api/v1/venues/null     America/Winnipeg
# 3       PNC Arena  /api/v1/venues/null     America/New_York
# 4    Honda Center  /api/v1/venues/null  America/Los_Angeles
#
#    venue_time_zone_offset venue_time_zone_tz
# 0                      -5                CDT
# 1                      -4                EDT
# 2                      -5                CDT
# 3                      -4                EDT
# 4                      -7                PDT

# %%
game_team_stats_file = "data/game_team_stats.csv"
game_team_stats_df = pd.read_csv(game_file)
game_team_stats_df.head(5)
# Out:
#       game_id    season type         date_time_GMT  away_team_id  \
# 0  2016020045  20162017    R  2016-10-19T00:30:00Z             4
# 1  2017020812  20172018    R  2018-02-07T00:00:00Z            24
# 2  2015020314  20152016    R  2015-11-24T01:00:00Z            21
# 3  2015020849  20152016    R  2016-02-17T00:00:00Z            52
# 4  2017020586  20172018    R  2017-12-30T03:00:00Z            20
#
#    home_team_id  away_goals  home_goals       outcome home_rink_side_start  \
# 0            16           4           7  home win REG                right
# 1             7           4           3   away win OT                 left
# 2            52           4           1  away win REG                right
# 3            12           1           2  home win REG                right
# 4            24           1           2  home win REG                 left
#
#             venue           venue_link   venue_time_zone_id  \
# 0   United Center  /api/v1/venues/null      America/Chicago
# 1  KeyBank Center  /api/v1/venues/null     America/New_York
# 2      MTS Centre  /api/v1/venues/null     America/Winnipeg
# 3       PNC Arena  /api/v1/venues/null     America/New_York
# 4    Honda Center  /api/v1/venues/null  America/Los_Angeles
#
#    venue_time_zone_offset venue_time_zone_tz
# 0                      -5                CDT
# 1                      -4                EDT
# 2                      -5                CDT
# 3                      -4                EDT
# 4                      -7                PDT

# %% [markdown]
# ### Connection to Postgres Database

# %%
# create connector
engine = create_engine(f'postgresql://postgres:{password}@localhost:5432/hockey_db')

# display tables in database
engine.table_names()
# Out:
# ['game', 'game_plays', 'game_teams_stats']

# %% [markdown]
# ### Load Dataframes into Postgres Database

# %% [markdown]
# ###### Game table

# %%
game_df.to_sql(
    name = 'game',
    con = engine,
    if_exists = 'append',
    index = False
)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#
# UndefinedColumn: column "date_time_GMT" of relation "game" does not exist
# LINE 1: INSERT INTO game (game_id, season, type, "date_time_GMT", aw...
#                                                  ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-26-a7d851e2fbff> in <module>
# ----> 1 game_df.to_sql(
#       2     name = 'game',
#       3     con = engine,
#       4     if_exists = 'append',
#       5     index = False
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2603         from pandas.io import sql
#    2604
# -> 2605         sql.to_sql(
#    2606             self,
#    2607             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     587         )
#     588
# --> 589     pandas_sql.to_sql(
#     590         frame,
#     591         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1404                 raise ValueError("inf cannot be used with MySQL") from err
#    1405             else:
# -> 1406                 raise err
#    1407
#    1408         if not name.isdigit() and not name.islower():
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1396
#    1397         try:
# -> 1398             table.insert(chunksize, method=method)
#    1399         except exc.SQLAlchemyError as err:
#    1400             # GH34431
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     828
#     829                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 830                 exec_insert(conn, keys, chunk_iter)
#     831
#     832     def _query_iterator(
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     745         """
#     746         data = [dict(zip(keys, row)) for row in data_iter]
# --> 747         conn.execute(self.table.insert(), data)
#     748
#     749     def _execute_insert_multi(self, conn, keys, data_iter):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#    1009             )
#    1010         else:
# -> 1011             return meth(self, multiparams, params)
#    1012
#    1013     def _execute_function(self, func, multiparams, params):
#
# ~\anaconda3\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params)
#     296     def _execute_on_connection(self, connection, multiparams, params):
#     297         if self.supports_execution:
# --> 298             return connection._execute_clauseelement(self, multiparams, params)
#     299         else:
#     300             raise exc.ObjectNotExecutableError(self)
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1122             )
#    1123
# -> 1124         ret = self._execute_context(
#    1125             dialect,
#    1126             dialect.execution_ctx_cls._init_compiled,
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1314
#    1315         except BaseException as e:
# -> 1316             self._handle_dbapi_exception(
#    1317                 e, statement, parameters, cursor, context
#    1318             )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1508                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1509             elif should_wrap:
# -> 1510                 util.raise_(
#    1511                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1512                 )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     180
#     181         try:
# --> 182             raise exception
#     183         finally:
#     184             # credit to
#
# ~\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1254                             break
#    1255                 if not evt_handled:
# -> 1256                     self.dialect.do_executemany(
#    1257                         cursor, statement, parameters, context
#    1258                     )
#
# ~\anaconda3\lib\site-packages\sqlalchemy\dialects\postgresql\psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     896     def do_executemany(self, cursor, statement, parameters, context=None):
#     897         if self.executemany_mode is EXECUTEMANY_DEFAULT:
# --> 898             cursor.executemany(statement, parameters)
#     899             return
#     900
#
# ProgrammingError: (psycopg2.errors.UndefinedColumn) column "date_time_GMT" of relation "game" does not exist
# LINE 1: INSERT INTO game (game_id, season, type, "date_time_GMT", aw...
#                                                  ^
#
# [SQL: INSERT INTO game (game_id, season, type, "date_time_GMT", away_team_id, home_team_id, away_goals, home_goals, outcome, home_rink_side_start, venue, venue_link, venue_time_zone_id, venue_time_zone_offset, venue_time_zone_tz) VALUES (%(game_id)s, %(season)s, %(type)s, %(date_time_GMT)s, %(away_team_id)s, %(home_team_id)s, %(away_goals)s, %(home_goals)s, %(outcome)s, %(home_rink_side_start)s, %(venue)s, %(venue_link)s, %(venue_time_zone_id)s, %(venue_time_zone_offset)s, %(venue_time_zone_tz)s)]
# [parameters: ({'game_id': 2016020045, 'season': 20162017, 'type': 'R', 'date_time_GMT': '2016-10-19T00:30:00Z', 'away_team_id': 4, 'home_team_id': 16, 'away_goals': 4, 'home_goals': 7, 'outcome': 'home win REG', 'home_rink_side_start': 'right', 'venue': 'United Center', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Chicago', 'venue_time_zone_offset': -5, 'venue_time_zone_tz': 'CDT'}, {'game_id': 2017020812, 'season': 20172018, 'type': 'R', 'date_time_GMT': '2018-02-07T00:00:00Z', 'away_team_id': 24, 'home_team_id': 7, 'away_goals': 4, 'home_goals': 3, 'outcome': 'away win OT', 'home_rink_side_start': 'left', 'venue': 'KeyBank Center', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/New_York', 'venue_time_zone_offset': -4, 'venue_time_zone_tz': 'EDT'}, {'game_id': 2015020314, 'season': 20152016, 'type': 'R', 'date_time_GMT': '2015-11-24T01:00:00Z', 'away_team_id': 21, 'home_team_id': 52, 'away_goals': 4, 'home_goals': 1, 'outcome': 'away win REG', 'home_rink_side_start': 'right', 'venue': 'MTS Centre', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Winnipeg', 'venue_time_zone_offset': -5, 'venue_time_zone_tz': 'CDT'}, {'game_id': 2015020849, 'season': 20152016, 'type': 'R', 'date_time_GMT': '2016-02-17T00:00:00Z', 'away_team_id': 52, 'home_team_id': 12, 'away_goals': 1, 'home_goals': 2, 'outcome': 'home win REG', 'home_rink_side_start': 'right', 'venue': 'PNC Arena', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/New_York', 'venue_time_zone_offset': -4, 'venue_time_zone_tz': 'EDT'}, {'game_id': 2017020586, 'season': 20172018, 'type': 'R', 'date_time_GMT': '2017-12-30T03:00:00Z', 'away_team_id': 20, 'home_team_id': 24, 'away_goals': 1, 'home_goals': 2, 'outcome': 'home win REG', 'home_rink_side_start': 'left', 'venue': 'Honda Center', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Los_Angeles', 'venue_time_zone_offset': -7, 'venue_time_zone_tz': 'PDT'}, {'game_id': 2016020610, 'season': 20162017, 'type': 'R', 'date_time_GMT': '2017-01-10T00:30:00Z', 'away_team_id': 15, 'home_team_id': 8, 'away_goals': 4, 'home_goals': 1, 'outcome': 'away win REG', 'home_rink_side_start': 'right', 'venue': 'Centre Bell', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Montreal', 'venue_time_zone_offset': -4, 'venue_time_zone_tz': 'EDT'}, {'game_id': 2015020606, 'season': 20152016, 'type': 'R', 'date_time_GMT': '2016-01-08T03:30:00Z', 'away_team_id': 10, 'home_team_id': 26, 'away_goals': 1, 'home_goals': 2, 'outcome': 'home win REG', 'home_rink_side_start': 'right', 'venue': 'STAPLES Center', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Los_Angeles', 'venue_time_zone_offset': -7, 'venue_time_zone_tz': 'PDT'}, {'game_id': 2017020240, 'season': 20172018, 'type': 'R', 'date_time_GMT': '2017-11-10T03:00:00Z', 'away_team_id': 23, 'home_team_id': 24, 'away_goals': 1, 'home_goals': 4, 'outcome': 'home win REG', 'home_rink_side_start': 'left', 'venue': 'Honda Center', 'venue_link': '/api/v1/venues/null', 'venue_time_zone_id': 'America/Los_Angeles', 'venue_time_zone_offset': -7, 'venue_time_zone_tz': 'PDT'}  ... displaying 10 of 26305 total bound parameter sets ...  {'game_id': 2018030417, 'season': 20182019, 'type': 'P', 'date_time_GMT': '2019-06-13T00:00:00Z', 'away_team_id': 19, 'home_team_id': 6, 'away_goals': 4, 'home_goals': 1, 'outcome': 'away win REG', 'home_rink_side_start': 'left', 'venue': 'TD Garden', 'venue_link': '/api/v1/venues/5085', 'venue_time_zone_id': 'America/New_York', 'venue_time_zone_offset': -5, 'venue_time_zone_tz': 'EST'}, {'game_id': 2018030417, 'season': 20182019, 'type': 'P', 'date_time_GMT': '2019-06-13T00:00:00Z', 'away_team_id': 19, 'home_team_id': 6, 'away_goals': 4, 'home_goals': 1, 'outcome': 'away win REG', 'home_rink_side_start': 'left', 'venue': 'TD Garden', 'venue_link': '/api/v1/venues/5085', 'venue_time_zone_id': 'America/New_York', 'venue_time_zone_offset': -5, 'venue_ ...
# (Background on this error at: http://sqlalche.me/e/13/f405)

# %% [markdown]
# ###### Game Plays table

# %% [markdown]
# ###### Game Teams Stats table
